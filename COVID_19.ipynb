# %% [markdown]
# # COVID_19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/COVID DATA.csv")

# %%
df.head(89)
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1  03/05/2020       97          1
# 1       2             1    2             1  03/06/2020       97          1
# 2       2             1    2             2  09/06/2020        1          2
# 3       2             1    1             1  12/06/2020       97          2
# 4       2             1    2             1  21/06/2020       97          2
# ..    ...           ...  ...           ...         ...      ...        ...
# 84      2             1    2             2  9999-99-99        2          2
# 85      2             1    1             1  9999-99-99       97          2
# 86      2             1    1             1  9999-99-99       97          2
# 87      2             1    2             1  9999-99-99       97          2
# 88      2             1    1             1  9999-99-99       97          2
#
#     AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %% [markdown]
# # Pandas Profiling

# %%
import pandas_profiling
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14212\1591302161.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
report=pandas_profiling.ProfileReport(df)

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-26 11:34:38.680967&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# we convert the people to 1 whose death_date is given and whose is missing we convert to 2

# %%
df['Death']=[2 if i=='9999-99-99' else 1 for i in df.DATE_DIED]

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.Death.value_counts()
# Out:
# 2    971633
# 1     76942
# Name: Death, dtype: int64

# %%
df.drop('DATE_DIED',inplace=True,axis=1)

# %%
df.PREGNANT.value_counts()
# Out:
# 97    523511
# 2     513179
# 1       8131
# 98      3754
# Name: PREGNANT, dtype: int64

# %%
df['PREGNANT']=[1 if i== 97 else i for i in df.PREGNANT]
df['PREGNANT']=[1 if i== 98 else i for i in df.PREGNANT]

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0            2             1    1             1       97          1   65
# 1            2             1    2             1       97          1   72
# 2            2             1    2             2        1          2   55
# 3            2             1    1             1       97          2   53
# 4            2             1    2             1       97          2   68
# ...        ...           ...  ...           ...      ...        ...  ...
# 1048570      2            13    2             1       97          2   40
# 1048571      1            13    2             2        2          2   51
# 1048572      2            13    2             1       97          2   55
# 1048573      2            13    2             1       97          2   28
# 1048574      2            13    2             1       97          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %% [markdown]
# convert 99,97,98 into null values and fill them with mode if mean of missing values are less than 20%

# %%
def missing_treat(x):
     x[(x == 97) | (x==98)| (x==99)] = np.nan
     if x.isna().mean() < 0.2:
        x=x.fillna(x.mode()[0])
     return x

# %%
df=df.apply(missing_treat)
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA   AGE  PREGNANT  \
# 0      2             1    1             1      NaN        1.0  65.0         2
# 1      2             1    2             1      NaN        1.0  72.0         1
#
#    DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  \
# 0       2.0   2.0  ...      2.0           1.0            2.0             2.0
# 1       2.0   2.0  ...      2.0           1.0            2.0             2.0
#
#    OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU  Death
# 0      2.0            2.0      2.0                     3  NaN      1
# 1      1.0            1.0      2.0                     5  NaN      1
#
# [2 rows x 21 columns]

# %%
df.isna().mean() # NOW 2 columns left whose missing values are more than 20% so we can drop those
# Out:
# USMER                   0.000000
# MEDICAL_UNIT            0.000000
# SEX                     0.000000
# PATIENT_TYPE            0.000000
# INTUBED                 0.816221
# PNEUMONIA               0.000000
# AGE                     0.000000
# PREGNANT                0.000000
# DIABETES                0.000000
# COPD                    0.000000
# ASTHMA                  0.000000
# INMSUPR                 0.000000
# HIPERTENSION            0.000000
# OTHER_DISEASE           0.000000
# CARDIOVASCULAR          0.000000
# OBESITY                 0.000000
# RENAL_CHRONIC           0.000000
# TOBACCO                 0.000000
# CLASIFFICATION_FINAL    0.000000
# ICU                     0.816377
# Death                   0.000000
# dtype: float64

# %%
df.drop(['INTUBED','ICU'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA   AGE  PREGNANT  \
# 0      2             1    1             1        1.0  65.0         2
# 1      2             1    2             1        1.0  72.0         1
#
#    DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0       2.0   2.0     2.0      2.0           1.0            2.0
# 1       2.0   2.0     2.0      2.0           1.0            2.0
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  \
# 0             2.0      2.0            2.0      2.0                     3
# 1             2.0      1.0            1.0      2.0                     5
#
#    Death
# 0      1
# 1      1

# %% [markdown]
# Outliers Capping by UPPERLIMIT=99% and lower limit=1%

# %%
def outliers_treat(x):
    x=x.clip(lower=x.quantile(0.01),upper=x.quantile(0.99))
    return x

# %%
df=df.apply(outliers_treat)

# %% [markdown]
# DRop duplicates rows

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA   AGE  PREGNANT  \
# 0            2           3.0    1             1        1.0  65.0         2
# 1            2           3.0    2             1        1.0  72.0         1
# 2            2           3.0    2             2        2.0  55.0         1
# 3            2           3.0    1             1        2.0  53.0         2
# 4            2           3.0    2             1        2.0  68.0         1
# ...        ...           ...  ...           ...        ...   ...       ...
# 1048534      1          12.0    1             1        2.0  61.0         2
# 1048540      1          12.0    1             1        2.0  80.0         2
# 1048547      1          12.0    2             1        2.0  62.0         1
# 1048554      2          12.0    1             2        1.0  63.0         2
# 1048561      2          12.0    2             1        2.0  45.0         1
#
# ...

# %% [markdown]
# drop those features which has varaince less than 5%

# %%
df.apply(lambda x:x.std()/x.mean())[df.apply(lambda x:x.std()/x.mean())<0.05]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Missing values Treatment
#
# Outliers Treatment
#
# Duplicate Values
#
# Drop those which has zero variance

# %% [markdown]
# # Visualization

# %%
#Visualization FOR all independent variable(X)

# %%
fig,ax=plt.subplots(2,5,figsize=(28,8))
sns.countplot(x=df.USMER ,ax=ax[0][0])
sns.countplot(x=df.MEDICAL_UNIT ,ax=ax[0][1])
sns.countplot(x=df.SEX ,ax=ax[0][2])
sns.countplot(x=df.PATIENT_TYPE ,ax=ax[0][3])
sns.countplot(x=df.PNEUMONIA ,ax=ax[0][4])
sns.histplot(data=df.AGE,bins=80,ax =ax[1][0])
sns.countplot(x=df.PREGNANT ,ax=ax[1][1])
sns.countplot(x=df.DIABETES ,ax=ax[1][2])
sns.countplot(x=df.COPD ,ax=ax[1][3])
sns.countplot(x=df.ASTHMA ,ax=ax[1][4])
plt.show()

# %%
fig,ax=plt.subplots(2,4,figsize=(24,8))
sns.countplot(x=df.INMSUPR ,ax=ax[0][0])
sns.countplot(x=df.HIPERTENSION ,ax=ax[0][1])
sns.countplot(x=df.OTHER_DISEASE ,ax=ax[0][2])
sns.countplot(x=df.CARDIOVASCULAR ,ax=ax[0][3])
sns.countplot(x=df.OBESITY ,ax=ax[1][0])
sns.countplot(x=df.RENAL_CHRONIC ,ax =ax[1][1])
sns.countplot(x=df.TOBACCO ,ax=ax[1][2])
sns.countplot(x=df.CLASIFFICATION_FINAL ,ax=ax[1][3])
plt.show()

# %%
# For dependent variable(Y)
sns.countplot(x=df.Death)
plt.show()

# %% [markdown]
# # Train_Test_split

# %%
# Tran_test_split
y=df['Death']
x=df.drop('Death',axis=1)
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y= train_test_split(x,y,test_size=0.3,random_state=100)

# %% [markdown]
# # Feature Selection Techniques

# %% [markdown]
# Now we do some feature selection and feature engineering

# %%
#VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF_DATA=pd.DataFrame()

# %%
VIF_DATA['Features']=x.columns

# %%
VIF_DATA['VIF']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]

# %%
VIF_DATA
# Out:
#                 Features        VIF
# 0                  USMER  10.725026
# 1           MEDICAL_UNIT   5.510910
# 2                    SEX  59.297427
# 3           PATIENT_TYPE  12.963294
# 4              PNEUMONIA  15.222217
# 5                    AGE  10.671532
# 6               PREGNANT  54.479021
# 7               DIABETES  15.020481
# 8                   COPD  53.444106
# 9                 ASTHMA  45.393631
# 10               INMSUPR  58.068462
# 11          HIPERTENSION  13.996204
# 12         OTHER_DISEASE  39.007711
# 13        CARDIOVASCULAR  42.193172
# 14               OBESITY  14.629751
# 15         RENAL_CHRONIC  45.476801
# 16               TOBACCO  24.542195
# 17  CLASIFFICATION_FINAL   8.940148

# %% [markdown]
# Drop those variables which creates large multicollinearity

# %%
df.drop(['SEX','PREGNANT','COPD','ASTHMA','INMSUPR','CARDIOVASCULAR','RENAL_CHRONIC'],axis=1,inplace=True)

# %% [markdown]
# RFE (Used to eliminate the feature one by one)

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'PATIENT_TYPE', 'PNEUMONIA', 'AGE', 'DIABETES',
#        'HIPERTENSION', 'OTHER_DISEASE', 'OBESITY', 'TOBACCO',
#        'CLASIFFICATION_FINAL', 'Death'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
rfe_model=RFE(DecisionTreeClassifier(),n_features_to_select=10,verbose=True)
rfe_model=rfe_model.fit(train_x,train_y)
# Out:
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.

# %%
l1=train_x.columns[rfe_model.support_]
l1
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'PATIENT_TYPE', 'PNEUMONIA', 'AGE', 'DIABETES',
#        'HIPERTENSION', 'OTHER_DISEASE', 'OBESITY', 'CLASIFFICATION_FINAL'],
#       dtype='object')

# %% [markdown]
# select k best (in this feature can be select one by one)

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
skb=SelectKBest(score_func=f_classif,k=10)
skb=skb.fit(train_x,train_y)

# %%
l2=train_x.columns[skb.get_support()]

# %%
final_list=list(set(set(l1).union(set(l2))))

# %%
final_list
# Out:
# ['OTHER_DISEASE',
#  'MEDICAL_UNIT',
#  'ASTHMA',
#  'AGE',
#  'RENAL_CHRONIC',
#  'DIABETES',
#  'CLASIFFICATION_FINAL',
#  'PATIENT_TYPE',
#  'OBESITY',
#  'HIPERTENSION',
#  'USMER',
#  'PNEUMONIA',
#  'SEX']

# %%
train_x_new=train_x[['OTHER_DISEASE','PNEUMONIA','DIABETES','CLASIFFICATION_FINAL','PATIENT_TYPE','AGE','ASTHMA','USMER',
                   'MEDICAL_UNIT','RENAL_CHRONIC','OBESITY','SEX','HIPERTENSION' ]]

test_x_new=test_x[['OTHER_DISEASE','PNEUMONIA','DIABETES','CLASIFFICATION_FINAL','PATIENT_TYPE','AGE','ASTHMA','USMER',
                   'MEDICAL_UNIT','RENAL_CHRONIC','OBESITY','SEX','HIPERTENSION' ]]

# %% [markdown]
# We used VIF, SELECTKBEST, RFE for feature selection

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
logmodel=LogisticRegression()
logmodel=logmodel.fit(train_x_new,train_y)
prediction=logmodel.predict(test_x_new)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
pred_prob_log=pd.DataFrame(logmodel.predict_proba(test_x_new))[1]
roc_auc_score(test_y,pred_prob_log)
# Out:
# 0.8227482669115787

# %%
print(classification_report(train_y,logmodel.predict(train_x_new)))
print(classification_report(test_y,prediction))
# 1-'Yes'
# 2-'NO'
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.33      0.41     27304
#            2       0.83      0.93      0.88     97321
#
#     accuracy                           0.80    124625
#    macro avg       0.69      0.63      0.64    124625
# weighted avg       0.77      0.80      0.77    124625
#
#               precision    recall  f1-score   support
#
#            1       0.55      0.33      0.41     11543
#            2       0.83      0.93      0.88     41868
#
#     accuracy                           0.80     53411
#    macro avg       0.69      0.63      0.64     53411
# weighted avg       0.77      0.80      0.78     53411

# %%
print(confusion_matrix(test_y,prediction))
# Out:
# [[ 3782  7761]
#  [ 3075 38793]]

# %%
print(accuracy_score(test_y,prediction))
# Out:
# 0.7971204433543652

# %% [markdown]
# # K_Nearest_Neighbors

# %% [markdown]
# Convert to standardization

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
st=st.fit(train_x_new)
st.transform(train_x_new)
train_x_std=pd.DataFrame(st.transform(train_x_new),columns=train_x_new.columns)
test_x_std=pd.DataFrame(st.transform(test_x_new),columns=train_x_new.columns)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid={'n_neighbors':list(range(5,15)),'weights':['distance','uniform']}
knn_grid=GridSearchCV(KNeighborsClassifier(),param_grid=param_grid,scoring='roc_auc',cv=5,verbose=True,n_jobs=-1)
knn_model=knn_grid.fit(train_x_std,train_y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %%
knn_model.best_params_
# Out:
# {'n_neighbors': 14, 'weights': 'uniform'}

# %%
knn_model=KNeighborsClassifier(n_neighbors=14,weights='uniform')

# %%
knn_model=knn_model.fit(train_x_std,train_y)

# %%
predictions=knn_model.predict(test_x_std)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
pred_prob_knn=pd.DataFrame(knn_model.predict_proba(test_x_std))[1]
roc_auc_score(test_y,pred_prob_knn)
# Out:
# 0.8064719588213203

# %%
print(classification_report(train_y,knn_model.predict(train_x_std)))
print(classification_report(test_y,predictions))
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#               precision    recall  f1-score   support
#
#            1       0.59      0.50      0.54     27304
#            2       0.86      0.90      0.88     97321
#
#     accuracy                           0.81    124625
#    macro avg       0.73      0.70      0.71    124625
# weighted avg       0.80      0.81      0.81    124625
#
#               precision    recall  f1-score   support
#
# ...

# %%
confusion_matrix(test_y,predictions)
# Out:
# array([[ 4757,  6786],
#        [ 4946, 36922]], dtype=int64)

# %% [markdown]
# # Naive _Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model=GaussianNB()

# %%
nb_model=nb_model.fit(train_x,train_y)

# %%
predict=nb_model.predict(test_x)

# %%
predict_prob_n=pd.DataFrame(nb_model.predict_proba(test_x))[1]
roc_auc_score(test_y,predict_prob_n)
# Out:
# 0.7909598303454608

# %%
print(classification_report(train_y,nb_model.predict(train_x)))
print(classification_report(test_y,predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.45      0.62      0.53     27304
#            2       0.88      0.79      0.83     97321
#
#     accuracy                           0.75    124625
#    macro avg       0.67      0.71      0.68    124625
# weighted avg       0.79      0.75      0.77    124625
#
#               precision    recall  f1-score   support
#
#            1       0.45      0.61      0.52     11543
#            2       0.88      0.79      0.83     41868
#
#     accuracy                           0.75     53411
#    macro avg       0.67      0.70      0.68     53411
# weighted avg       0.79      0.75      0.77     53411

# %% [markdown]
# # Random Forest Classifier

# %%
#Random Forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
rm_grid={'max_features':[8,10,12,14,16],'n_estimators':[100,200,250,300,350]}

# %%
grid_rm=GridSearchCV(RandomForestClassifier(),cv=5,param_grid=rm_grid,verbose=True,n_jobs=-1,scoring='roc_auc')

# %%
rm_model=grid_rm.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits

# %%
rm_model.best_params_

# %%
rkm=RandomForestClassifier(max_features=8,n_estimators=200,oob_score=True,verbose=True,n_jobs=-1)

# %%
rkm.fit(train_x,train_y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   31.0s finished
# RandomForestClassifier(max_features=8, n_estimators=200, n_jobs=-1,
#                        oob_score=True, verbose=True)

# %%
pred_prob_test=pd.DataFrame(rkm.predict_proba(test_x))[1]
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    2.4s finished

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(test_y,pred_prob_test)
# Out:
# 0.7338657879405497

# %%
predictions_r=rkm.predict(test_x)
print(classification_report(train_y,rkm.predict(train_x)))
print(classification_report(test_y,predictions))
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    2.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    5.1s finished
#               precision    recall  f1-score   support
#
#            1       0.88      0.81      0.84     27304
#            2       0.95      0.97      0.96     97321
#
#     accuracy                           0.93    124625
#    macro avg       0.91      0.89      0.90    124625
# weighted avg       0.93      0.93      0.93    124625
#
#               precision    recall  f1-score   support
#
# ...

# %%
accuracy_score(test_y,predictions)
# Out:
# 0.7803448727790155

# %% [markdown]
# # Bagging

# %%
# Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
pargrid_ada = {'n_estimators': [80, 100, 120, 140, 160, 200]}

gscv_bagging = GridSearchCV(estimator=BaggingClassifier(), 
                        param_grid=pargrid_ada, 
                        cv=5,
                        verbose=True, n_jobs=-1)

# %%
gscv_results = gscv_bagging.fit(train_x, train_y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits

# %%
gscv_results.best_params_
# Out:
# {'n_estimators': 140}

# %%
gscv_results.best_score_
# Out:
# 0.7295085255767302

# %%
gb=BaggingClassifier(n_estimators=14,n_jobs=-1,verbose=True,oob_score=True)

# %%
gb.fit(train_x,train_y)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:   41.8s remaining:   41.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   42.7s finished
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:706: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:712: RuntimeWarning: invalid value encountered in true_divide
#   oob_decision_function = predictions / predictions.sum(axis=1)[:, np.newaxis]
# BaggingClassifier(n_estimators=14, n_jobs=-1, oob_score=True, random_state=100,
#                   verbose=True)

# %%
pred_prob_gb=pd.DataFrame(gb.predict_proba(test_x))[1]
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.5s remaining:    0.5s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.8s finished

# %%
roc_auc_score(test_y,pred_prob_gb)
# Out:
# 0.7107196951817341

# %%
pred_gb=gb.predict(test_x)
print(classification_report(test_y,pred_gb))
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.4s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.4s finished
#               precision    recall  f1-score   support
#
#            1       0.34      0.33      0.33     11543
#            2       0.82      0.82      0.82     41868
#
#     accuracy                           0.72     53411
#    macro avg       0.58      0.58      0.58     53411
# weighted avg       0.71      0.72      0.71     53411

# %% [markdown]
# # Adaboost

# %%
#Adaboost
from sklearn.ensemble import AdaBoostClassifier

# %%
pargrid_ada = {'n_estimators': [100, 200, 400, 600, 800],
               'learning_rate': [10 ** x for x in range(-3, 3)]}

# %%
gscv_ada = GridSearchCV(estimator=AdaBoostClassifier(), 
                        param_grid=pargrid_ada, 
                        cv=5,
                        verbose=True, n_jobs=-1)

# %%
gscv_ada.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'n_estimators': [100, 200, 400, 600, 800]},
#              verbose=True)

# %%
gscv_ada.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 800}

# %%
gscv_ada.best_score_
# Out:
# 0.7987883650952858

# %%
ada_model=AdaBoostClassifier(n_estimators=800,learning_rate=0.1)

# %%
ada_model.fit(train_x,train_y)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=800)

# %%
pred_prob_ad=pd.DataFrame(ada_model.predict_proba(test_x))[1]

# %%
roc_auc_score(test_y,pred_prob_ad)
# Out:
# 0.8359985549564606

# %%
print(classification_report(test_y,pd.DataFrame(ada_model.predict(test_x))))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.36      0.44     11543
#            2       0.84      0.92      0.88     41868
#
#     accuracy                           0.80     53411
#    macro avg       0.70      0.64      0.66     53411
# weighted avg       0.78      0.80      0.78     53411

# %% [markdown]
# # XGBOOST

# %%
from xgboost import XGBClassifier

# %%
pargrid_ada={'n_estimators': [100, 200, 400, 600, 800],
               'learning_rate': [10 ** x for x in range(-3, 3)]}

# %%
grid_xg=GridSearchCV(XGBClassifier(),param_grid=pargrid_ada,verbose=True,n_jobs=-1,cv=5)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(train_y)

# %%
grid_xg.fit(train_x,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
# ...

# %%
grid_xg.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 800}

# %%
xgb_model=XGBClassifier(learning_rate=0.01,n_estimators=800,n_jobs=-1)

# %%
xgb_model.fit(train_x,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=800, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
pred_prob_xgb=pd.DataFrame(xgb_model.predict_proba(test_x))[1]

# %%
roc_auc_score(test_y,pred_prob_xgb)
# Out:
# 0.847421143215658

# %% [markdown]
# #XGBosst has highest roc_auc_score of 0.85

# %% [markdown]
# # END
